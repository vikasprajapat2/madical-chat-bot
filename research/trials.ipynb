# %%
print("ok")
# Out:
# The kernel failed to start as 'TypeAliasType' could not be imported from 'c:\Users\i7\AppData\Local\Programs\Python\Python310\lib\site-packages\typing_extensions.py'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.
