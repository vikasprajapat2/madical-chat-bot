# %%
print("ok")
# Out:
# ok

# %%
# %pwd
# Out:
# 'd:\\madical-chat-bot\\research'

# %%
from langchain_community.document_loaders import PyPDFLoader, DirectoryLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
#extract data from pdf
# Tabline: Edit| Test| explain| Document| Ask
def load_pdf_files(data):
    loader=DirectoryLoader(data, glob="*.pdf", loader_cls=PyPDFLoader)
    documents=loader.load()

    return documents

# %%
extracted_data=load_pdf_files(data="data/")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 extracted_data=load_pdf_files(data="data/")
#
# Cell In[13], line 5, in load_pdf_files(data)
#       3 def load_pdf_files(data):
#       4     loader=DirectoryLoader(data, glob="*.pdf", loader_cls=PyPDFLoader)
# ----> 5     documents=loader.load()
#       7     return documents
#
# File d:\madical-chat-bot\.venv\lib\site-packages\langchain_community\document_loaders\directory.py:117, in DirectoryLoader.load(self)
#     115 def load(self) -> List[Document]:
#     116     """Load documents."""
# --> 117     return list(self.lazy_load())
#
# File d:\madical-chat-bot\.venv\lib\site-packages\langchain_community\document_loaders\directory.py:123, in DirectoryLoader.lazy_load(self)
#     121 p = Path(self.path)
#     122 if not p.exists():
# --> 123     raise FileNotFoundError(f"Directory not found: '{self.path}'")
#     124 if not p.is_dir():
#     125     raise ValueError(f"Expected directory, got file: '{self.path}'")
#
# FileNotFoundError: Directory not found: 'data/'
